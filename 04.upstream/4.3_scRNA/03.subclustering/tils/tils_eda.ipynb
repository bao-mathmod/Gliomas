# %%
library(Seurat)
library(tidyverse)
# Out:
# Warning message:
# “package ‘Seurat’ was built under R version 4.4.3”
# Loading required package: SeuratObject
#
# Warning message:
# “package ‘SeuratObject’ was built under R version 4.4.3”
# Loading required package: sp
#
# Warning message:
# “package ‘sp’ was built under R version 4.4.3”
#
# Attaching package: ‘SeuratObject’
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, t
#
#
# Warning message:
# “package ‘tidyverse’ was built under R version 4.4.3”
# Warning message:
# “package ‘tibble’ was built under R version 4.4.3”
# Warning message:
# “package ‘tidyr’ was built under R version 4.4.3”
# Warning message:
# “package ‘readr’ was built under R version 4.4.3”
# Warning message:
# “package ‘dplyr’ was built under R version 4.4.3”
# Warning message:
# “package ‘forcats’ was built under R version 4.4.3”
# Warning message:
# “package ‘lubridate’ was built under R version 4.4.3”
# ...

# %%
tils <- readRDS('/mnt/18T/chibao/gliomas/data/upstream/scRNA/official/integrated_v5_optimized/adult/subclusters/tils/tils_final_integrated.rds')
tils
# Out:
# An object of class Seurat
# 68328 features across 78031 samples within 2 assays
# Active assay: SCT (29722 features, 3000 variable features)
#  3 layers present: counts, data, scale.data
#  1 other assay present: RNA
#  3 dimensional reductions calculated: pca, harmony, umap.harmony

# %%
tils@meta.data |> head()
# Out:
#                                                                                         orig.ident
# PRJNA1125010__PRJNA1125010__filtered_feature_bc_matrix__SAMN41882099_AAATGGAGTGCGAGTA-1 PRJNA1125010
# PRJNA1125010__PRJNA1125010__filtered_feature_bc_matrix__SAMN41882099_AACCAACCAGGCGATA-1 PRJNA1125010
# PRJNA1125010__PRJNA1125010__filtered_feature_bc_matrix__SAMN41882099_AAGACTCGTGCCGAAA-1 PRJNA1125010
# PRJNA1125010__PRJNA1125010__filtered_feature_bc_matrix__SAMN41882099_AATAGAGTCGTAGCCG-1 PRJNA1125010
# PRJNA1125010__PRJNA1125010__filtered_feature_bc_matrix__SAMN41882099_ACCGTTCAGGATACCG-1 PRJNA1125010
# PRJNA1125010__PRJNA1125010__filtered_feature_bc_matrix__SAMN41882099_ACCGTTCTCGCACGGT-1 PRJNA1125010
#                                                                                         nCount_RNA
# PRJNA1125010__PRJNA1125010__filtered_feature_bc_matrix__SAMN41882099_AAATGGAGTGCGAGTA-1 8516
# ...

# %%
options(repr.plot.width = 8, repr.plot.height = 6)
DimPlot(tils, reduction = 'umap.harmony', group.by = 'SCT_snn_res.0.08', label = TRUE)
# Out:
# plot without title

# %%
Idents(tils) <- 'SCT_snn_res.0.2'

# %%
obj <- tils

# %%
obj <- PrepSCTFindMarkers(obj, assay = "SCT", verbose = TRUE)
# Out:
# Found 10 SCT models. Recorrecting SCT counts using minimum median counts: 1487

# %%
Idents(tils) <- 'SCT_snn_res.0.08'

# %%
# Find all markers for all clusters
all_markers <- FindAllMarkers(
  object = obj,
  assay = "SCT",
  only.pos = TRUE,
  min.pct = 0.25,
  logfc.threshold = 0.25,
  test.use = "wilcox"
)
# Out:
# Calculating cluster 0
#
# Calculating cluster 1
#
# Calculating cluster 2
#
# Calculating cluster 3
#
# Calculating cluster 4
#
# Calculating cluster 5
#
# Calculating cluster 6
#
# Calculating cluster 7
#
# Calculating cluster 8
#
# Calculating cluster 9
#
# Calculating cluster 10
#
# Calculating cluster 11
#
# Calculating cluster 12
#
# Calculating cluster 13
#
# Calculating cluster 14
#
# Calculating cluster 15

# %%
cluster0 <- all_markers %>% filter(cluster == 0) %>% arrange(desc(avg_log2FC))
cluster1 <- all_markers %>% filter(cluster == 1) %>% arrange(desc(avg_log2FC))
cluster2 <- all_markers %>% filter(cluster == 2) %>% arrange(desc(avg_log2FC))
cluster3 <- all_markers %>% filter(cluster == 3) %>% arrange(desc(avg_log2FC))
cluster4 <- all_markers %>% filter(cluster == 4) %>% arrange(desc(avg_log2FC))
cluster5 <- all_markers %>% filter(cluster == 5) %>% arrange(desc(avg_log2FC))
cluster6 <- all_markers %>% filter(cluster == 6) %>% arrange(desc(avg_log2FC))
cluster7 <- all_markers %>% filter(cluster == 7) %>% arrange(desc(avg_log2FC))
cluster8 <- all_markers %>% filter(cluster == 8) %>% arrange(desc(avg_log2FC))

# %%
cluster2 |> head(10)
# Out:
#           p_val avg_log2FC pct.1 pct.2 p_val_adj cluster gene
# DUSP2     0     2.293509   0.499 0.163 0         2       DUSP2
# DUSP1     0     2.291392   0.425 0.176 0         2       DUSP1
# GZMH      0     2.121267   0.630 0.216 0         2       GZMH
# TRGC2     0     2.092099   0.283 0.077 0         2       TRGC2
# CD8B      0     1.996814   0.440 0.139 0         2       CD8B
# GZMK      0     1.877994   0.505 0.146 0         2       GZMK
# CCL5      0     1.761072   0.964 0.430 0         2       CCL5
# CD8A      0     1.683196   0.440 0.159 0         2       CD8A
# LINC01871 0     1.661560   0.446 0.149 0         2       LINC01871
# FCRL6     0     1.579888   0.289 0.094 0         2       FCRL6

# %%
Idents(tils) <- 'SCT_snn_res.0.2'

# %%
# Find all markers for all clusters
all_markers_2 <- FindAllMarkers(
  object = obj,
  assay = "SCT",
  only.pos = TRUE,
  min.pct = 0.25,
  logfc.threshold = 0.25,
  test.use = "wilcox"
)
# Out:
# Calculating cluster 0
#
# Calculating cluster 1
#
# Calculating cluster 2
#
# Calculating cluster 3
#
# Calculating cluster 4
#
# Calculating cluster 5
#
# Calculating cluster 6
#
# Calculating cluster 7
#
# Calculating cluster 8
#
# Calculating cluster 9
#
# Calculating cluster 10
#
# Calculating cluster 11
#
# Calculating cluster 12
#
# Calculating cluster 13
#
# Calculating cluster 14
#
# Calculating cluster 15

# %%
cluster0 <- all_markers_2 %>% filter(cluster == 0) %>% arrange(desc(avg_log2FC))
cluster1 <- all_markers_2 %>% filter(cluster == 1) %>% arrange(desc(avg_log2FC))
cluster2 <- all_markers_2 %>% filter(cluster == 2) %>% arrange(desc(avg_log2FC))
cluster3 <- all_markers_2 %>% filter(cluster == 3) %>% arrange(desc(avg_log2FC))
cluster4 <- all_markers_2 %>% filter(cluster == 4) %>% arrange(desc(avg_log2FC))
cluster5 <- all_markers_2 %>% filter(cluster == 5) %>% arrange(desc(avg_log2FC))
cluster6 <- all_markers_2 %>% filter(cluster == 6) %>% arrange(desc(avg_log2FC))
cluster7 <- all_markers_2 %>% filter(cluster == 7) %>% arrange(desc(avg_log2FC))
cluster8 <- all_markers_2 %>% filter(cluster == 8) %>% arrange(desc(avg_log2FC))
cluster9 <- all_markers_2 %>% filter(cluster == 9) %>% arrange(desc(avg_log2FC))
cluster10 <- all_markers_2 %>% filter(cluster == 10) %>% arrange(desc(avg_log2FC))
cluster11 <- all_markers_2 %>% filter(cluster == 11) %>% arrange(desc(avg_log2FC))
cluster12 <- all_markers_2 %>% filter(cluster == 12) %>% arrange(desc(avg_log2FC))
cluster13 <- all_markers_2 %>% filter(cluster == 13) %>% arrange(desc(avg_log2FC))
cluster14 <- all_markers_2 %>% filter(cluster == 14) %>% arrange(desc(avg_log2FC))
cluster15 <- all_markers_2 %>% filter(cluster == 15) %>% arrange(desc(avg_log2FC))

# %%
DimPlot(tils, reduction = 'umap.harmony', group.by = 'SCT_snn_res.0.2', label = TRUE)
# Out:
# plot without title

# %%
cluster8 |> head(10)
cluster9 |> head(10)
# Out:
#              p_val avg_log2FC pct.1 pct.2 p_val_adj cluster gene
# ABCB11       0     2.111319   0.406 0.104 0         8       ABCB1
# EPB41L4A-AS1 0     2.077280   0.467 0.121 0         8       EPB41L4A-AS1
# SNHG91       0     2.042410   0.464 0.123 0         8       SNHG9
# MVD          0     2.001974   0.256 0.068 0         8       MVD
# YARS11       0     1.903288   0.422 0.124 0         8       YARS1
# RARS1        0     1.879338   0.278 0.077 0         8       RARS1
# CNOT12       0     1.715167   0.385 0.124 0         8       CNOT1
# ARPC5L3      0     1.701310   0.476 0.165 0         8       ARPC5L
# MRPL10       0     1.696173   0.262 0.083 0         8       MRPL10
# SPDYE2       0     1.660162   0.275 0.086 0         8       SPDYE2
#               p_val avg_log2FC pct.1 pct.2 p_val_adj cluster gene
# CCR71         0     2.048991   0.418 0.118 0         9       CCR7
# RHBDD2        0     1.997301   0.280 0.076 0         9       RHBDD2
# ...
