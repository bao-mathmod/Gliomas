# %%
library(dplyr)
library(tidyverse)
# Out:
# Warning message:
# “package ‘dplyr’ was built under R version 4.4.3”
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Warning message:
# “package ‘tidyverse’ was built under R version 4.4.3”
# Warning message:
# “package ‘ggplot2’ was built under R version 4.4.3”
# Warning message:
# “package ‘tibble’ was built under R version 4.4.3”
# Warning message:
# “package ‘tidyr’ was built under R version 4.4.3”
# Warning message:
# “package ‘readr’ was built under R version 4.4.3”
# Warning message:
# “package ‘purrr’ was built under R version 4.4.3”
# Warning message:
# “package ‘stringr’ was built under R version 4.4.3”
# Warning message:
# “package ‘forcats’ was built under R version 4.4.3”
# Warning message:
# “package ‘lubridate’ was built under R version 4.4.3”
# ...

# %%
test <- read_tsv("/mnt/12T/chibao/data/official_data/metadata/official/split2/PRJNA869964/latest.tsv")
test |> head()
# Out:
# Rows: 384 Columns: 20
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (19): study_accession, sample_accession, experiment_accession, run_acces...
# dbl  (1): read_count
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   study_accession sample_accession experiment_accession run_accession
# 1 PRJNA869964     SAMN30346615     SRX17100993          SRR21086022
# 2 PRJNA869964     SAMN30346611     SRX17100999          SRR21086037
# 3 PRJNA869964     SAMN30346609     SRX17100969          SRR21086043
# 4 PRJNA869964     SAMN30346609     SRX17100969          SRR21086045
# 5 PRJNA869964     SAMN30346609     SRX17100969          SRR21086046
# 6 PRJNA869964     SAMN30346614     SRX17100994          SRR21086048
#   scientific_name
# 1 Homo sapiens
# 2 Homo sapiens
# 3 Homo sapiens
# 4 Homo sapiens
# 5 Homo sapiens
# ...

# %%
unique(test$run_accession)
# Out:
#   [1] "SRR21086022" "SRR21086037" "SRR21086043" "SRR21086045" "SRR21086046"
#   [6] "SRR21086048" "SRR21086051" "SRR21086052" "SRR21086053" "SRR21086056"
#  [11] "SRR21086058" "SRR21086059" "SRR21086062" "SRR21086065" "SRR21086072"
#  [16] "SRR21086075" "SRR21086077" "SRR21086078" "SRR21086080" "SRR21086082"
#  [21] "SRR21086088" "SRR21086089" "SRR21086091" "SRR21086093" "SRR21086095"
#  [26] "SRR21086101" "SRR21086103" "SRR21086107" "SRR21086110" "SRR21086111"
#  [31] "SRR21086114" "SRR21086121" "SRR21086124" "SRR21086125" "SRR21086130"
#  [36] "SRR21086131" "SRR21086134" "SRR21086137" "SRR21086138" "SRR21086139"
#  [41] "SRR21086140" "SRR21086145" "SRR21086147" "SRR21086154" "SRR21086162"
#  [46] "SRR21086164" "SRR21086166" "SRR21086168" "SRR21086170" "SRR21086173"
#  [51] "SRR21086186" "SRR21086188" "SRR21086190" "SRR21086191" "SRR21086192"
#  [56] "SRR21086193" "SRR21086196" "SRR21086197" "SRR21086207" "SRR21086209"
# ...

# %%
sample <- read_tsv("/mnt/12T/chibao/data/official_data/metadata_full/PRJNA1081384/PRJNA1081384_metadata.tsv")
sample |> head(5)
# Out:
# Rows: 28 Columns: 59
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr  (42): run_accession, study_accession, study_title, experiment_accession...
# dbl   (8): organism_taxid, total_spots, total_size, run_total_spots, run_tot...
# lgl   (8): sample_title, experiment_alias, ena_fastq_http, ena_fastq_ftp, ag...
# dttm  (1): public_date
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   run_accession study_accession
# 1 SRR28124856   SRP492102
# 2 SRR28124857   SRP492102
# 3 SRR28124858   SRP492102
# 4 SRR28124859   SRP492102
# 5 SRR28124860   SRP492102
#   study_title
# 1 Single-nucleus and spatial landscape of the sub-ventricular zone in human glioblastoma
# 2 Single-nucleus and spatial landscape of the sub-ventricular zone in human glioblastoma
# ...

# %%
unique(sample$sample_accession)
# Out:
#  [1] "SRS20595505" "SRS20595149" "SRS20595148" "SRS20595146" "SRS20595150"
#  [6] "SRS20595504" "SRS20595147" "SRS20595145" "SRS20595144" "SRS20595142"
# [11] "SRS20595143" "SRS20595141" "SRS20595502" "SRS20595140" "SRS20595139"
# [16] "SRS20595637" "SRS20595503" "SRS20595137" "SRS20595136" "SRS20595501"
# [21] "SRS20595138" "SRS20595639" "SRS20595133" "SRS20595500" "SRS20595134"
# [26] "SRS20595135" "SRS20595130" "SRS20595128"

# %%
sample |> select(sample_accession, tissue, experiment_title, library_source)
# Out:
#    sample_accession tissue
# 1  SRS20595505      tumor svz sample of glioblastoma patient mis3
# 2  SRS20595149      tumor svz sample of glioblastoma patient mis2
# 3  SRS20595148      tumor svz sample of glioblastoma patient mis1
# 4  SRS20595146      tumor svz sample of glioblastoma patient 9
# 5  SRS20595150      tumor svz sample of glioblastoma patient 8
# 6  SRS20595504      tumor svz sample of glioblastoma patient 7
# 7  SRS20595147      tumor svz sample of glioblastoma patient 22
# 8  SRS20595145      tumor svz sample of glioblastoma patient 20
# 9  SRS20595144      tumor svz sample of glioblastoma patient 17
# 10 SRS20595142      tumor svz sample of glioblastoma patient 16
# 11 SRS20595143      tumor svz sample of glioblastoma patient 12
# 12 SRS20595141      tumor svz sample of glioblastoma patient 10
# 13 SRS20595502      tumor mass sample of glioblastoma patient mis3
# 14 SRS20595140      tumor mass sample of glioblastoma patient mis1
# ...
